# %%
import numpy as np
import pandas as pd
import holoviews as hv
import hvplot.pandas # noqa: F401
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="eea0ee43-0575-4f49-a028-36a97193eb7f" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ### data
#  - https://www.data.jma.go.jp/stats/etrn/view/monthly_s3.php?prec_no=44&block_no=47662

# %%
value = [
[1876,24.3,28.6]
,[1877,26.5,31]
,[1878,26,29.8]
,[1879,26.1,30.4]
,[1880,24.2,28]
,[1881,24,27.9]
,[1882,24.2,28.2]
,[1883,23.7,27.2]
,[1884,23.4,27]
,[1885,23.1,26.6]
,[1886,25,29.3]
,[1887,23.6,27.4]
,[1888,24.5,28.3]
,[1889,23.4,26.9]
,[1890,23.5,27.3]
,[1891,24.9,28.7]
,[1892,25.7,29.7]
,[1893,25.3,30.2]
,[1894,26.8,31.6]
,[1895,22.1,25.7]
,[1896,24.1,28.1]
,[1897,22.9,26.5]
,[1898,25.9,30.3]
,[1899,23.2,26.9]
,[1900,22.8,26.5]
,[1901,22.1,26]
,[1902,21.8,25.6]
,[1903,23.2,26.9]
,[1904,24.8,28.7]
,[1905,23.3,27.3]
,[1906,23.5,27]
,[1907,22.7,26.6]
,[1908,22.1,25.9]
,[1909,24.3,28.3]
,[1910,23,26.4]
,[1911,24.5,28.5]
,[1912,24.3,28.5]
,[1913,23.3,27.8]
,[1914,25.5,30]
,[1915,24.2,28.8]
,[1916,23.9,28.1]
,[1917,25.7,30.3]
,[1918,26,30.2]
,[1919,23.6,27.5]
,[1920,26.1,30.6]
,[1921,24.3,28.4]
,[1922,25,29.2]
,[1923,24,27.8]
,[1924,26.1,30.8]
,[1925,23.2,27.1]
,[1926,24.6,28.9]
,[1927,26,30.2]
,[1928,23.4,26.6]
,[1929,25.9,29.8]
,[1930,26.3,30]
,[1931,21.8,25.1]
,[1932,25.7,29.4]
,[1933,26.6,30.7]
,[1934,23.9,27.5]
,[1935,24.3,28.3]
,[1936,24.9,28.9]
,[1937,26.3,29.8]
,[1938,25,29.1]
,[1939,26.5,30.7]
,[1940,26.9,31.8]
,[1941,23.7,27.4]
,[1942,27.5,31.9]
,[1943,25.1,29]
,[1944,25.6,30.3]
,[1945,22,26.1]
,[1946,26.2,30.8]
,[1947,25.7,30.5]
,[1948,26,30.6]
,[1949,25.3,29.5]
,[1950,26.5,31]
,[1951,24.3,28.3]
,[1952,24.3,28.2]
,[1953,24.7,28.3]
,[1954,22.3,25.7]
,[1955,27.6,31.8]
,[1956,24.2,28.1]
,[1957,24.4,27.8]
,[1958,24.9,28.9]
,[1959,26.1,29.9]
,[1960,25.8,29.8]
,[1961,27.4,31.9]
,[1962,25.1,28.8]
,[1963,25.7,30.1]
,[1964,25.5,29.6]
,[1965,24.2,27.3]
,[1966,24.4,27.9]
,[1967,26.3,30]
,[1968,24.7,28]
,[1969,25,28.7]
,[1970,25.4,29.1]
,[1971,25.8,29.5]
,[1972,25.2,28.8]
,[1973,26.1,30.2]
,[1974,23.4,26.9]
,[1975,25.6,29.4]
,[1976,23.9,27.6]
,[1977,25.8,29.8]
,[1978,27.8,31.5]
,[1979,25.2,28.5]
,[1980,23.8,27.4]
,[1981,26.3,30]
,[1982,23.1,26.1]
,[1983,23.8,27.1]
,[1984,26.2,30]
,[1985,26.3,30.2]
,[1986,23.9,27.2]
,[1987,27,30.6]
,[1988,22.4,25.2]
,[1989,24.1,27.4]
,[1990,25.7,29.2]
,[1991,26.7,30.1]
,[1992,25.5,29.2]
,[1993,22.5,25.3]
,[1994,28.3,31.8]
,[1995,26.4,29.6]
,[1996,26.2,30]
,[1997,26.6,30.7]
,[1998,25.3,29]
,[1999,25.9,29.9]
,[2000,27.7,31.6]
,[2001,28.5,33]
,[2002,28,31.7]
,[2003,22.8,26]
,[2004,28.5,33.1]
,[2005,25.6,29.1]
,[2006,25.6,28.6]
,[2007,24.4,27.4]
,[2008,27,30.9]
,[2009,26.3,29.3]
,[2010,28,31.6]
,[2011,27.3,30.9]
,[2012,26.4,30.1]
,[2013,27.3,31.4]
,[2014,26.8,30.5]
,[2015,26.2,30.1]
,[2016,25.4,29.7]
,[2017,27.3,31.8]
,[2018,28.3,32.7]
,[2019,24.1,27.5]
,[2020,24.3,27.7]
,[2021,25.9,30.3]
,[2022,27.4,31.7]
,[2023,28.7,33.9]
,[2024,28.7,33.5]
]

value = np.array(value)

# %%
df = pd.DataFrame(value[:,1:], columns=['MeanTemp', 'MaxTemp'], index=value[:,0].astype(int))
df.index.name = 'Year'
df
# Out:
#       MeanTemp  MaxTemp
# Year
# 1876      24.3     28.6
# 1877      26.5     31.0
# 1878      26.0     29.8
# 1879      26.1     30.4
# 1880      24.2     28.0
# ...        ...      ...
# 2020      24.3     27.7
# 2021      25.9     30.3
# 2022      27.4     31.7
# 2023      28.7     33.9
# 2024      28.7     33.5
#
# [149 rows x 2 columns]

# %%
fig = df.hvplot.line(title='Monthly average daily mean temperature and daily maximum temperature in Tokyo in July', xlabel='Year', ylabel='Temperature (°C)', width=800, height=400, legend='top_left')
fig
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Year]   (value)

# %%
hv.save(fig, 'TokyoJuly.html')
